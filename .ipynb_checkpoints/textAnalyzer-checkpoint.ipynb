# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import csv
import datetime as dt
from sklearn.manifold import TSNE

import re
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
import string
import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
from nltk.corpus import stopwords
from tensorflow.contrib.tensorboard.plugins import projector

# %%
# Give a folder path as an argument with '--log_dir' to save
# TensorBoard summaries. Default is a log folder in current directory.
current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
FLAGS, unparsed = parser.parse_known_args()

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(FLAGS.log_dir):
  os.makedirs(FLAGS.log_dir)

# %%
def text_process(text):
    '''
    Takes in a string of text, then
    1. Removes all punctuation and stopwords
    3. Returns the clean text as a list of words
    '''
    text = str(text).lower()
    text = text[1:]

    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)

    output = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

    return ' '.join(output)


def read_data(filename):
    # extract the csv file with each cell as a list of strings
    file = pd.read_csv(filename, usecols=range(2, 23))
    for row in range(0, 1989):
        for col in range(0, 21):
            file.iloc[row, col] = text_process(str(file.iloc[row, col]))
    return file

# %% [markdown]
# ### print(train)

# %%
cleanedNews = pd.read_csv("./rsc/cleanedNews.csv")

def convert_string(array):
    numRows = len(array)
    numCol = len(array.iloc[0])
    wordString = []
    for row in range(0,numRows):
        for col in range(0,numCol):
            wordString +=(array.iloc[row, col].split())
    return wordString

outputWordList = convert_string(cleanedNews)

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = len(set(outputWordList))
print(vocabulary_size)

outputWordList = set(outputWordList)
# Out:
# 40503

# %%
def build_dataset(words, n_words):
  #Process raw inputs into a dataset.
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# %%
# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(
    outputWordList, vocabulary_size)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 1], ('oct', 1), ('golani', 1), ('42million', 1), ('gulfstates', 1)]
# Sample data [3, 4, 5, 33, 6, 8, 9, 7757, 10226, 14] ['42million', 'gulfstates', 'conflictthe', 'large', 'fortunate', 'plutonium', 'upheavals', 'f447', 'sweets', 'pedestrians']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])
# Out:
# 4 gulfstates -> 5 conflictthe
# 4 gulfstates -> 3 42million
# 5 conflictthe -> 4 gulfstates
# 5 conflictthe -> 33 large
# 33 large -> 5 conflictthe
# 33 large -> 6 fortunate
# 6 fortunate -> 8 plutonium
# 6 fortunate -> 33 large

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

# %%
with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal(
              [vocabulary_size, embedding_size],
              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()

  # Step 5: Begin training.
  num_steps = 100001

  with tf.Session(graph=graph) as session:
      # Open a writer to write summaries.
      writer = tf.summary.FileWriter(FLAGS.log_dir, session.graph)

      # We must initialize all variables before we use them.
      init.run()
      print('Initialized')

      average_loss = 0
      for step in xrange(num_steps):
          batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                      skip_window)
          feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

          # Define metadata variable.
          run_metadata = tf.RunMetadata()

          # We perform one update step by evaluating the optimizer op (including it
          # in the list of returned values for session.run()
          # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
          # Feed metadata variable to session for visualizing the graph in TensorBoard.
          _, summary, loss_val = session.run(
              [optimizer, merged, loss],
              feed_dict=feed_dict,
              run_metadata=run_metadata)
          average_loss += loss_val

          # Add returned summaries to writer in each step.
          writer.add_summary(summary, step)
          # Add metadata to visualize the graph for the last run.
          if step == (num_steps - 1):
              writer.add_run_metadata(run_metadata, 'step%d' % step)

          if step % 2000 == 0:
              if step > 0:
                  average_loss /= 2000
              # The average loss is an estimate of the loss over the last 2000 batches.
              print('Average loss at step ', step, ': ', average_loss)
              average_loss = 0

          # Note that this is expensive (~20% slowdown if computed every 500 steps)
          if step % 10000 == 0:
              sim = similarity.eval()
              for i in xrange(valid_size):
                  valid_word = reverse_dictionary[valid_examples[i]]
                  top_k = 8  # number of nearest neighbors
                  nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                  log_str = 'Nearest to %s:' % valid_word
                  for k in xrange(top_k):
                      close_word = reverse_dictionary[nearest[k]]
                      log_str = '%s %s,' % (log_str, close_word)
                  print(log_str)
      final_embeddings = normalized_embeddings.eval()

      # Write corresponding labels for the embeddings.
      with open(FLAGS.log_dir + '/metadata.tsv', 'w') as f:
          for i in xrange(vocabulary_size):
              f.write(reverse_dictionary[i] + '\n')

      # Save the model for checkpoints.
      saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))

      # Create a configuration for visualizing embeddings with the labels in TensorBoard.
      config = projector.ProjectorConfig()
      embedding_conf = config.embeddings.add()
      embedding_conf.tensor_name = embeddings.name
      embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
      projector.visualize_embeddings(writer, config)

  writer.close()


  # Step 6: Visualize the embeddings.


  # pylint: disable=missing-docstring
  # Function to draw visualization of distance between embeddings.
  def plot_with_labels(low_dim_embs, labels, filename):
      assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
      plt.figure(figsize=(18, 18))  # in inches
      for i, label in enumerate(labels):
          x, y = low_dim_embs[i, :]
          plt.scatter(x, y)
          plt.annotate(
              label,
              xy=(x, y),
              xytext=(5, 2),
              textcoords='offset points',
              ha='right',
              va='bottom')

      plt.savefig(filename)


  try:
      # pylint: disable=g-import-not-at-top
      from sklearn.manifold import TSNE
      import matplotlib.pyplot as plt

      tsne = TSNE(
          perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
      plot_only = 500
      low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
      labels = [reverse_dictionary[i] for i in xrange(plot_only)]
      plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

  except ImportError as ex:
      print('Please install sklearn, matplotlib, and scipy to show embeddings.')
      print(ex)
# Out:
# Initialized
# Average loss at step  0 :  263.098693848
# Nearest to 4577: tally, triumphalism, coincides, ofdaisy, ussponsored, ahara, civilized, rife,
# Nearest to airdrop: kazakhstans, clubs, dystopia, govto, sciences, 120000, mismatch, 3x,
# Nearest to dog: brotherhoodwhich, damn, ilan, lynchings, gibb, moscowhavana, ouse, nt,
# Nearest to valery: event, aldouri, mac, workday, nigde, beset, tides, rnfilmed,
# Nearest to guns: eurabia, wendelstein, spices, argentinian, antiislam, plummeted, wners, tfvatican,
# Nearest to surging: binladin, schaeuble, passedout, gangraping, maced, barclays, atal, alta,
# Nearest to slatecom: persists, gruesome, line, eert, swissmanufactured, rabbit, sofitel, clocked,
# Nearest to rampageriots: uriosity, alawites, bicycle, gruesome, disintegrating, 9squaremeter, latif, completion,
# Nearest to 16m: machinery, employ, drunkenly, appalled, gm, moving, fuel, insensitivity,
# Nearest to oubting: ignoble, secondclass, spyware, kbs, quantified, spontaneous, ablo, athletes,
# Nearest to unequivocal: leyva, johan, dipping, diamondencrusted, antiporn, mmr, nowdefunct, gilbert,
# Nearest to advert: elsisi, risishit, taiji, boo, employment, allgirl, miracles, foie,
# Nearest to hatever: daivd, nabbed, dementia, angladeshi, showpiece, chief, departure, predecessors,
# Nearest to large: licenses, apparently, narwhal, decapitating, oneblock, narrative, morgenson, inward,
# Nearest to levin: heet, blockaded, glittering, weight, emissionscapture, lowfat, memorialize, peanut,
# Nearest to kissed: shoes, pulled, fishy, 000strong, julie, nospying, bedsheets, tomtato,
# Average loss at step  2000 :  149.487586514
# Average loss at step  4000 :  98.4740676193
# Average loss at step  6000 :  75.7285278101
# Average loss at step  8000 :  58.1807254663
# Average loss at step  10000 :  40.8069521654
# Nearest to 4577: tally, triumphalism, ofdaisy, ahara, ussponsored, coincides, rnspeed, civilized,
# Nearest to airdrop: kazakhstans, clubs, govto, 3x, 120000, sciences, millennium, moshe,
# Nearest to dog: brotherhoodwhich, lynchings, gibb, damn, ouse, moscowhavana, purported, ilan,
# Nearest to valery: event, aldouri, mac, nigde, workday, mushrooms, tides, reutersaly,
# Nearest to guns: argentinian, wendelstein, antiislam, eurabia, aulo, plummeted, spices, unravels,
# Nearest to surging: binladin, schaeuble, atal, gangraping, barclays, maced, passedout, vafamehr,
# Nearest to slatecom: gruesome, persists, swissmanufactured, rehabilitation, eert, clocked, sofitel, ukbound,
# Nearest to rampageriots: bicycle, uriosity, alawites, disintegrating, fraudsters, gruesome, verse, 9squaremeter,
# Nearest to 16m: moving, omits, fuel, 161, gm, machinery, appalled, informing,
# Nearest to oubting: ignoble, secondclass, spyware, quantified, spontaneous, kbs, athletes, donations,
# Nearest to unequivocal: leyva, diamondencrusted, johan, startup, antiporn, pparently, mmr, nowdefunct,
# Nearest to advert: elsisi, risishit, taiji, dual, foie, allgirl, kea, spewing,
# Nearest to hatever: daivd, nabbed, chief, dementia, predecessors, angladeshi, mesopotamian, bruniare,
# Nearest to large: narwhal, licenses, apparently, narrative, oneblock, decapitating, inward, attractiveness,
# Nearest to levin: heet, landsbankinn, glittering, weight, peanut, estonians, miscalculate, emissionscapture,
# Nearest to kissed: shoes, fishy, pulled, julie, bedsheets, 000strong, nonpartisan, nospying,
# Average loss at step  12000 :  25.3896698252
# Average loss at step  14000 :  15.5555702478
# Average loss at step  16000 :  10.109797074
# Average loss at step  18000 :  6.96367240089
# Average loss at step  20000 :  4.79887363058
# Nearest to 4577: tally, triumphalism, ofdaisy, ahara, ussponsored, coincides, rife, rnspeed,
# Nearest to airdrop: kazakhstans, clubs, 120000, dystopia, freaking, yitzhar, sciences, automated,
# Nearest to dog: brotherhoodwhich, lynchings, gibb, damn, ilan, purported, ouse, moscowhavana,
# Nearest to valery: event, mac, trader, nigde, workday, aldouri, tides, mushrooms,
# Nearest to guns: argentinian, antiislam, eurabia, aulo, wendelstein, plummeted, unravels, wners,
# Nearest to surging: binladin, schaeuble, gangraping, barclays, atal, passedout, maced, vafamehr,
# Nearest to slatecom: gruesome, persists, swissmanufactured, rehabilitation, sofitel, clocked, hepatitisc, line,
# Nearest to rampageriots: bicycle, uriosity, alawites, disintegrating, gruesome, verse, fraudsters, 9squaremeter,
# Nearest to 16m: moving, employ, omits, fuel, gm, 161, machinery, appalled,
# Nearest to oubting: ignoble, secondclass, spyware, quantified, spontaneous, athletes, bayeux, hands,
# Nearest to unequivocal: leyva, diamondencrusted, johan, mmr, antiporn, dipping, nowdefunct, startup,
# Nearest to advert: elsisi, risishit, taiji, dual, kea, spewing, allgirl, foie,
# Nearest to hatever: daivd, nabbed, chief, predecessors, mesopotamian, bolivar, mamba, bruniare,
# Nearest to large: decapitating, licenses, apparently, narwhal, oneblock, inward, narrative, mirhossein,
# Nearest to levin: landsbankinn, glittering, heet, estonians, weight, peanut, xboxes, emissionscapture,
# Nearest to kissed: shoes, pulled, fishy, 000strong, bedsheets, nonpartisan, nospying, eightyear,
# Average loss at step  22000 :  3.519604242
# Average loss at step  24000 :  2.439215056
# Average loss at step  26000 :  1.89409202728
# Average loss at step  28000 :  1.47277893521
# Average loss at step  30000 :  1.21537260151
# Nearest to 4577: tally, triumphalism, ahara, ofdaisy, ussponsored, 006, coincides, rnspeed,
# Nearest to airdrop: kazakhstans, clubs, dystopia, 120000, automated, freaking, tomtato, yitzhar,
# Nearest to dog: brotherhoodwhich, gibb, lynchings, damn, ilan, ouse, purported, moscowhavana,
# Nearest to valery: event, mac, trader, nigde, aldouri, workday, mushrooms, tides,
# Nearest to guns: antiislam, argentinian, eurabia, aulo, wendelstein, plummeted, spices, wners,
# Nearest to surging: binladin, schaeuble, gangraping, barclays, passedout, atal, vafamehr, maced,
# Nearest to slatecom: gruesome, persists, swissmanufactured, sofitel, rehabilitation, clocked, hepatitisc, devices,
# Nearest to rampageriots: bicycle, uriosity, alawites, disintegrating, fraudsters, verse, gruesome, 9squaremeter,
# Nearest to 16m: employ, moving, omits, machinery, fuel, appalled, gm, informing,
# Nearest to oubting: ignoble, secondclass, spyware, spontaneous, quantified, athletes, hands, bayeux,
# Nearest to unequivocal: leyva, diamondencrusted, johan, mmr, dipping, antiporn, nowdefunct, pparently,
# Nearest to advert: elsisi, risishit, taiji, dual, kea, allgirl, misidentified, spewing,
# Nearest to hatever: daivd, nabbed, chief, predecessors, mesopotamian, bruniare, mamba, apwf120413,
# Nearest to large: decapitating, licenses, apparently, narwhal, oneblock, inward, ribes, mirhossein,
# Nearest to levin: landsbankinn, glittering, heet, estonians, peanut, xboxes, weight, verbytsky,
# Nearest to kissed: shoes, pulled, fishy, 000strong, nonpartisan, bedsheets, nospying, eightyear,
# Average loss at step  32000 :  1.00394123144
# Average loss at step  34000 :  0.787953649774
# Average loss at step  36000 :  0.718755400419
# Average loss at step  38000 :  0.600747593284
# Average loss at step  40000 :  0.552230619565
# Nearest to 4577: tally, ahara, triumphalism, ofdaisy, ussponsored, 006, coincides, rnspeed,
# Nearest to airdrop: kazakhstans, clubs, dystopia, 120000, tomtato, automated, freaking, yitzhar,
# Nearest to dog: brotherhoodwhich, gibb, lynchings, damn, ilan, ouse, moscowhavana, purported,
# Nearest to valery: event, mac, trader, nigde, aldouri, mushrooms, workday, tides,
# Nearest to guns: antiislam, argentinian, eurabia, wendelstein, aulo, plummeted, spices, wners,
# Nearest to surging: binladin, schaeuble, gangraping, barclays, passedout, atal, maced, vafamehr,
# Nearest to slatecom: persists, gruesome, swissmanufactured, sofitel, rehabilitation, clocked, devices, eert,
# Nearest to rampageriots: bicycle, uriosity, alawites, disintegrating, fraudsters, verse, gruesome, completion,
# Nearest to 16m: employ, moving, machinery, 161, appalled, gm, omits, informing,
# Nearest to oubting: ignoble, secondclass, spyware, spontaneous, quantified, athletes, hands, bayeux,
# Nearest to unequivocal: leyva, diamondencrusted, johan, mmr, dipping, antiporn, nowdefunct, pparently,
# Nearest to advert: elsisi, risishit, taiji, dual, allgirl, kea, misidentified, employment,
# Nearest to hatever: daivd, nabbed, chief, predecessors, mesopotamian, bruniare, mamba, odwyers,
# Nearest to large: decapitating, licenses, narwhal, apparently, oneblock, inward, ribes, mirhossein,
# Nearest to levin: landsbankinn, heet, glittering, estonians, xboxes, peanut, weight, verbytsky,
# Nearest to kissed: shoes, pulled, fishy, 000strong, nonpartisan, nospying, bedsheets, planted,
# Average loss at step  42000 :  0.500178415418
# Average loss at step  44000 :  0.44007412342
# Average loss at step  46000 :  0.411747281529
# Average loss at step  48000 :  0.382241029471
# Average loss at step  50000 :  0.359534467831
# Nearest to 4577: ahara, triumphalism, tally, ofdaisy, 006, ussponsored, coincides, rnspeed,
# Nearest to airdrop: kazakhstans, clubs, dystopia, 120000, tomtato, automated, freaking, yitzhar,
# Nearest to dog: brotherhoodwhich, gibb, lynchings, damn, ilan, moscowhavana, ouse, purported,
# Nearest to valery: event, mac, trader, nigde, aldouri, mushrooms, workday, tides,
# Nearest to guns: antiislam, argentinian, eurabia, plummeted, wendelstein, aulo, spices, wners,
# Nearest to surging: binladin, schaeuble, barclays, gangraping, passedout, atal, maced, vafamehr,
# Nearest to slatecom: persists, gruesome, swissmanufactured, sofitel, rehabilitation, devices, line, eert,
# Nearest to rampageriots: bicycle, uriosity, alawites, fraudsters, disintegrating, gruesome, verse, completion,
# Nearest to 16m: employ, moving, machinery, appalled, 161, gm, omits, informing,
# Nearest to oubting: secondclass, ignoble, spyware, spontaneous, quantified, hands, athletes, bayeux,
# Nearest to unequivocal: leyva, johan, diamondencrusted, mmr, dipping, antiporn, nowdefunct, pparently,
# Nearest to advert: elsisi, risishit, taiji, dual, allgirl, kea, misidentified, employment,
# Nearest to hatever: daivd, nabbed, chief, predecessors, mesopotamian, bruniare, mamba, bolivar,
# Nearest to large: decapitating, licenses, narwhal, apparently, oneblock, inward, ribes, mirhossein,
# Nearest to levin: landsbankinn, peanut, heet, xboxes, estonians, glittering, weight, verbytsky,
# Nearest to kissed: shoes, pulled, fishy, 000strong, nonpartisan, nospying, 3500, bedsheets,
# Average loss at step  52000 :  0.333426215552
# Average loss at step  54000 :  0.31486958839
# Average loss at step  56000 :  0.302711992882
# Average loss at step  58000 :  0.289159747452
# Average loss at step  60000 :  0.276324926525
# Nearest to 4577: ahara, triumphalism, ofdaisy, tally, 006, ussponsored, coincides, rnspeed,
# Nearest to airdrop: kazakhstans, clubs, dystopia, 120000, tomtato, automated, freaking, yitzhar,
# Nearest to dog: brotherhoodwhich, gibb, lynchings, damn, moscowhavana, ilan, ouse, purported,
# Nearest to valery: event, mac, trader, nigde, aldouri, mushrooms, workday, tides,
# Nearest to guns: antiislam, argentinian, eurabia, plummeted, wendelstein, aulo, spices, wners,
# Nearest to surging: binladin, schaeuble, barclays, gangraping, atal, passedout, maced, vafamehr,
# Nearest to slatecom: persists, gruesome, swissmanufactured, sofitel, rehabilitation, devices, line, eert,
# Nearest to rampageriots: bicycle, uriosity, alawites, disintegrating, fraudsters, gruesome, verse, completion,
# Nearest to 16m: employ, machinery, moving, 161, appalled, gm, informing, omits,
# Nearest to oubting: secondclass, ignoble, spyware, spontaneous, quantified, hands, athletes, bayeux,
# Nearest to unequivocal: leyva, johan, diamondencrusted, mmr, antiporn, dipping, nowdefunct, pparently,
# Nearest to advert: elsisi, risishit, taiji, dual, allgirl, misidentified, kea, spewing,
# Nearest to hatever: daivd, chief, nabbed, predecessors, mesopotamian, bruniare, odwyers, mamba,
# Nearest to large: decapitating, licenses, narwhal, apparently, oneblock, inward, ribes, mirhossein,
# Nearest to levin: landsbankinn, peanut, estonians, heet, xboxes, glittering, weight, verbytsky,
# Nearest to kissed: shoes, pulled, fishy, 000strong, nonpartisan, nospying, 3500, bedsheets,
# Average loss at step  62000 :  0.266837957077
# Average loss at step  64000 :  0.250882316031
# Average loss at step  66000 :  0.243796801746
# Average loss at step  68000 :  0.234198488645
# Average loss at step  70000 :  0.225109421328
# Nearest to 4577: ahara, triumphalism, ofdaisy, tally, 006, ussponsored, coincides, erdict,
# Nearest to airdrop: kazakhstans, clubs, dystopia, tomtato, automated, 120000, yitzhar, nspired,
# Nearest to dog: brotherhoodwhich, gibb, lynchings, damn, ilan, moscowhavana, ouse, purported,
# Nearest to valery: event, mac, trader, nigde, aldouri, mushrooms, workday, tides,
# Nearest to guns: antiislam, argentinian, eurabia, wendelstein, plummeted, aulo, spices, wners,
# Nearest to surging: binladin, schaeuble, barclays, gangraping, atal, passedout, maced, vafamehr,
# Nearest to slatecom: persists, gruesome, swissmanufactured, sofitel, rehabilitation, devices, line, eert,
# Nearest to rampageriots: bicycle, uriosity, alawites, disintegrating, fraudsters, verse, gruesome, completion,
# Nearest to 16m: employ, machinery, 161, moving, appalled, gm, informing, omits,
# Nearest to oubting: secondclass, ignoble, spyware, spontaneous, quantified, hands, athletes, bayeux,
# Nearest to unequivocal: leyva, johan, diamondencrusted, mmr, antiporn, dipping, nowdefunct, pparently,
# Nearest to advert: elsisi, risishit, taiji, dual, allgirl, misidentified, kea, spewing,
# Nearest to hatever: daivd, chief, nabbed, predecessors, mesopotamian, odwyers, bruniare, mamba,
# Nearest to large: decapitating, licenses, narwhal, apparently, oneblock, inward, ribes, mirhossein,
# Nearest to levin: landsbankinn, peanut, heet, xboxes, estonians, weight, glittering, blockaded,
# Nearest to kissed: shoes, pulled, fishy, 000strong, nonpartisan, 3500, nospying, bedsheets,
# Average loss at step  72000 :  0.217268090785
# Average loss at step  74000 :  0.211346378818
# Average loss at step  76000 :  0.203191725962
# Average loss at step  78000 :  0.196550556842
# Average loss at step  80000 :  0.190838879369
# Nearest to 4577: ahara, triumphalism, ofdaisy, tally, 006, ussponsored, coincides, rnspeed,
# Nearest to airdrop: kazakhstans, clubs, dystopia, automated, tomtato, 120000, yitzhar, nspired,
# Nearest to dog: brotherhoodwhich, gibb, lynchings, damn, moscowhavana, ilan, ouse, purported,
# Nearest to valery: event, mac, trader, nigde, aldouri, mushrooms, workday, tides,
# Nearest to guns: antiislam, argentinian, eurabia, wendelstein, plummeted, aulo, spices, wners,
# Nearest to surging: binladin, schaeuble, barclays, gangraping, atal, passedout, maced, vafamehr,
# Nearest to slatecom: persists, gruesome, swissmanufactured, sofitel, rehabilitation, devices, line, eert,
# Nearest to rampageriots: bicycle, uriosity, alawites, disintegrating, fraudsters, verse, gruesome, completion,
# Nearest to 16m: employ, 161, machinery, moving, appalled, gm, informing, omits,
# Nearest to oubting: secondclass, ignoble, spyware, spontaneous, quantified, hands, athletes, bayeux,
# Nearest to unequivocal: leyva, johan, diamondencrusted, mmr, antiporn, dipping, nowdefunct, pparently,
# Nearest to advert: elsisi, risishit, taiji, dual, allgirl, misidentified, spewing, kea,
# Nearest to hatever: daivd, chief, nabbed, predecessors, mesopotamian, odwyers, bruniare, mamba,
# Nearest to large: decapitating, licenses, narwhal, apparently, oneblock, inward, ribes, mirhossein,
# Nearest to levin: landsbankinn, peanut, heet, xboxes, weight, estonians, glittering, blockaded,
# Nearest to kissed: shoes, pulled, fishy, 000strong, nonpartisan, 3500, nospying, bedsheets,
# Average loss at step  82000 :  0.186179989994
# Average loss at step  84000 :  0.180433094542
# Average loss at step  86000 :  0.177220070451
# Average loss at step  88000 :  0.171812365085
# Average loss at step  90000 :  0.167281178493
# Nearest to 4577: ahara, triumphalism, ofdaisy, tally, 006, ussponsored, coincides, erdict,
# Nearest to airdrop: kazakhstans, clubs, dystopia, automated, tomtato, 120000, freaking, nspired,
# Nearest to dog: brotherhoodwhich, gibb, lynchings, damn, ilan, moscowhavana, ouse, purported,
# Nearest to valery: event, mac, trader, nigde, aldouri, mushrooms, workday, tides,
# Nearest to guns: antiislam, argentinian, eurabia, plummeted, wendelstein, spices, aulo, wners,
# Nearest to surging: binladin, schaeuble, barclays, gangraping, atal, passedout, maced, vafamehr,
# Nearest to slatecom: persists, gruesome, swissmanufactured, sofitel, devices, rehabilitation, line, eert,
# Nearest to rampageriots: bicycle, uriosity, alawites, disintegrating, fraudsters, verse, gruesome, completion,
# Nearest to 16m: machinery, 161, employ, moving, appalled, informing, gm, fuel,
# Nearest to oubting: secondclass, ignoble, spyware, quantified, spontaneous, hands, athletes, bayeux,
# Nearest to unequivocal: leyva, johan, diamondencrusted, mmr, antiporn, dipping, nowdefunct, pparently,
# Nearest to advert: elsisi, risishit, taiji, dual, allgirl, misidentified, spewing, kea,
# Nearest to hatever: daivd, chief, nabbed, predecessors, mesopotamian, odwyers, mamba, bruniare,
# Nearest to large: decapitating, licenses, apparently, narwhal, oneblock, inward, mirhossein, ribes,
# Nearest to levin: landsbankinn, peanut, xboxes, heet, estonians, weight, glittering, blockaded,
# Nearest to kissed: shoes, pulled, fishy, 000strong, nonpartisan, 3500, bedsheets, nospying,
# Average loss at step  92000 :  0.162835175458
# Average loss at step  94000 :  0.161135051794
# Average loss at step  96000 :  0.154225433249
# Average loss at step  98000 :  0.15169405634
# Average loss at step  100000 :  0.147982207313
# Nearest to 4577: ahara, triumphalism, ofdaisy, tally, 006, ussponsored, coincides, private,
# Nearest to airdrop: kazakhstans, clubs, dystopia, automated, tomtato, 120000, freaking, yitzhar,
# Nearest to dog: brotherhoodwhich, gibb, lynchings, ilan, damn, moscowhavana, ouse, purported,
# Nearest to valery: event, mac, trader, nigde, aldouri, mushrooms, workday, tides,
# Nearest to guns: antiislam, argentinian, eurabia, plummeted, wendelstein, spices, aulo, wners,
# Nearest to surging: binladin, schaeuble, barclays, gangraping, atal, passedout, maced, vafamehr,
# Nearest to slatecom: persists, gruesome, swissmanufactured, sofitel, devices, line, rehabilitation, eert,
# Nearest to rampageriots: bicycle, uriosity, alawites, fraudsters, disintegrating, verse, gruesome, completion,
# Nearest to 16m: machinery, employ, 161, moving, appalled, informing, gm, fuel,
# Nearest to oubting: secondclass, ignoble, spyware, quantified, spontaneous, hands, athletes, bayeux,
# Nearest to unequivocal: leyva, johan, diamondencrusted, mmr, antiporn, dipping, nowdefunct, pparently,
# Nearest to advert: elsisi, risishit, taiji, dual, allgirl, misidentified, kea, spewing,
# Nearest to hatever: daivd, chief, nabbed, predecessors, mesopotamian, odwyers, bolivar, mamba,
# Nearest to large: decapitating, licenses, apparently, narwhal, oneblock, inward, mirhossein, ribes,
# Nearest to levin: landsbankinn, peanut, xboxes, estonians, heet, weight, glittering, blockaded,
# Nearest to kissed: shoes, pulled, fishy, nonpartisan, 000strong, 3500, bedsheets, nospying,

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

# %%
# set array sizes, TODO optimize this later, prepares the dataset for vector representation
cleanedNews = pd.read_csv("./rsc/cleanedNews.csv")
arrayNews = pd.DataFrame(cleanedNews)
  
for i in range(0,len(cleanedNews)):
    for j in range(0, len(cleanedNews.iloc[0])):
        arrayNews.iloc[i,j] = str(cleanedNews.iloc[i,j]).split()

# %%
arrayNews.to_csv("./rsc/cleanedNewsArrays")
revisedNews = pd.read_csv("./rsc/cleanedNewsArrays", usecols = [x for x in range(1,21)])

revisedNews.head()
# Out:
#                                                 Top1  \
# 0  ['georgia', 'downs', 'two', 'russian', 'warpla...
# 1  ['wont', 'america', 'nato', 'help', 'us', 'won...
# 2  ['remember', 'adorable', '9yearold', 'sang', '...
# 3  ['us', 'refuses', 'israel', 'weapons', 'attack...
# 4          ['experts', 'admit', 'legalise', 'drugs']
#
#                                                 Top2  \
# 0             ['breaking', 'musharraf', 'impeached']
# 1   ['bush', 'puts', 'foot', 'georgian', 'conflict']
# 2         ['russia', 'ends', 'georgia', 'operation']
# 3  ['president', 'ordered', 'attack', 'tskhinvali...
# 4  ['war', 'south', 'osetia', '89', 'pictures', '...
#
#                                                 Top3  \
# 0  ['russia', 'today', 'columns', 'troops', 'roll...
# 1  ['jewish', 'georgian', 'minister', 'thanks', '...
# 2      ['sexual', 'harassment', 'would', 'children']
# 3  ['israel', 'clears', 'troops', 'killed', 'reut...
# 4  ['swedish', 'wrestler', 'ara', 'abrahamian', '...
#
#                                                 Top4  \
# 0  ['russian', 'tanks', 'moving', 'towards', 'cap...
# 1  ['georgian', 'army', 'flees', 'disarray', 'rus...
# 2  ['alqaeda', 'losing', 'support', 'iraq', 'brut...
# 3  ['britains', 'policy', 'tough', 'drugs', 'poin...
# 4  ['russia', 'exaggerated', 'death', 'toll', 'so...
#
#                                                 Top5  \
# 0  ['afghan', 'children', 'raped', 'impunity', 'u...
# 1  ['olympic', 'opening', 'ceremony', 'fireworks'...
# 2  ['ceasefire', 'georgia', 'putin', 'outmaneuver...
# 3  ['body', '14', 'year', 'old', 'found', 'trunk'...
# 4  ['missile', 'killed', '9', 'inside', 'pakistan...
#
#                                                 Top6  \
# 0  ['150', 'russian', 'tanks', 'entered', 'south'...
# 1  ['mossad', 'fraudulent', 'new', 'zealand', 'pa...
# 2  ['microsoft', 'intel', 'tried', 'kill', 'xo', ...
# 3  ['china', 'moved', '10', 'million', 'quake', '...
# 4  ['rushdie', 'condemns', 'random', 'houses', 'r...
#
#                                                 Top7  \
# 0  ['breaking', 'georgia', 'invades', 'south', 'o...
# 1  ['russia', 'angered', 'israeli', 'military', '...
# 2  ['stratfor', 'russogeorgian', 'war', 'balance'...
# 3  ['bush', 'announces', 'operation', 'get', 'rus...
# 4  ['poland', 'us', 'agree', 'missle', 'defense',...
#
#                                                 Top8  \
# 0  ['enemy', 'combatent', 'trials', 'nothing', 's...
# 1  ['american', 'citizen', 'living', 'sossetia', ...
# 2  ['im', 'trying', 'get', 'sense', 'whole', 'geo...
# 3  ['russian', 'forces', 'sink', 'georgian', 'shi...
# 4  ['russians', 'conquer', 'tblisi', 'bet', 'seri...
#
#                                                 Top9  \
# 0  ['georgian', 'troops', 'retreat', 'osettain', ...
# 1  ['welcome', 'world', 'war', 'iv', 'high', 'def...
# 2  ['us', 'military', 'surprised', 'timing', 'swi...
# 3  ['commander', 'navy', 'air', 'reconnaissance',...
# 4  ['russia', 'exaggerating', 'south', 'ossetian'...
#
#                                                Top10  \
# 0         ['us', 'prep', 'georgia', 'war', 'russia']
# 1  ['georgias', 'move', 'mistake', 'monumental', ...
# 2  ['us', 'beats', 'war', 'drum', 'iran', 'dumps'...
# 3  ['92', 'cnn', 'readers', 'russias', 'actions',...
# 4  ['musharraf', 'expected', 'resign', 'rather', ...
#
#                                                Top11  \
# 0  ['rice', 'gives', 'green', 'light', 'israel', ...
# 1  ['russia', 'presses', 'deeper', 'georgia', 'us...
# 2  ['gorbachev', 'georgian', 'military', 'attacke...
# 3  ['usa', 'send', 'fleet', 'black', 'sea', 'help...
# 4  ['moscow', 'made', 'plans', 'months', 'ago', '...
#
#                                                Top12  \
# 0  ['announcingclass', 'action', 'lawsuit', 'beha...
# 1  ['abhinav', 'bindra', 'wins', 'first', 'ever',...
# 2  ['cnn', 'use', 'footage', 'tskhinvali', 'ruins...
# 3  ['us', 'warns', 'israeli', 'plan', 'strike', '...
# 4        ['russias', 'response', 'georgia', 'right']
#
#                                                Top13  \
# 0  ['sorussia', 'georgia', 'war', 'nyts', 'top', ...
# 1  ['us', 'ship', 'heads', 'arctic', 'define', 't...
# 2  ['beginning', 'war', 'olympics', 'opening', 'v...
# 3  ['intriguing', 'cyberalliance', 'two', 'estoni...
# 4  ['nigeria', 'handed', 'potentially', 'oilrich'...
#
#                                                Top14  \
# 0  ['china', 'tells', 'bush', 'stay', 'countries'...
# 1  ['drivers', 'jerusalem', 'taxi', 'station', 't...
# 2  ['55', 'pyramids', 'large', 'luxor', 'stacked'...
# 3  ['cnn', 'effect', 'georgia', 'schools', 'russi...
# 4  ['us', 'poland', 'agreed', 'preliminary', 'dea...
#
#                                                Top15  \
# 0          ['world', 'war', 'iii', 'start', 'today']
# 1  ['french', 'team', 'stunned', 'phelps', '4x100...
# 2          ['11', 'top', 'party', 'cities', 'world']
# 3        ['russias', 'response', 'georgia', 'right']
# 4  ['russia', 'apparently', 'sabotaging', 'infras...
#
#                                                Top16  \
# 0  ['georgia', 'invades', 'south', 'ossetia', 'ru...
# 1  ['israel', 'us', 'behind', 'georgian', 'aggres...
# 2  ['us', 'troops', 'still', 'georgia', 'know', '...
# 3                   ['elephants', 'extinct', '2020']
# 4  ['bank', 'analyst', 'forecast', 'georgian', 'c...
#
#                                                Top17  \
# 0       ['alqaeda', 'faces', 'islamist', 'backlash']
# 1  ['believe', 'tv', 'neither', 'russian', 'georg...
# 2        ['russias', 'response', 'georgia', 'right']
# 3  ['us', 'humanitarian', 'missions', 'soon', 'ge...
# 4  ['georgia', 'confict', 'could', 'set', 'back',...
#
#                                                Top18  \
# 0  ['condoleezza', 'rice', 'us', 'would', 'act', ...
# 1  ['riots', 'still', 'going', 'montreal', 'canad...
# 2  ['gorbachev', 'accuses', 'us', 'making', 'seri...
# 3      ['georgias', 'ddos', 'came', 'us', 'sources']
# 4  ['war', 'caucasus', 'much', 'product', 'americ...
#
#                                                Top19  \
# 0  ['busy', 'day', 'european', 'union', 'approved...
# 1  ['china', 'overtake', 'us', 'largest', 'manufa...
# 2  ['russia', 'georgia', 'nato', 'cold', 'war', '...
# 3  ['russian', 'convoy', 'heads', 'georgia', 'vio...
# 4  ['nonmedia', 'photos', 'south', 'ossetiageorgi...
#
#                                                Top20
# 0  ['georgia', 'withdraw', '1000', 'soldiers', 'i...
# 1                ['war', 'south', 'ossetia', 'pics']
# 2  ['remember', 'adorable', '62yearold', 'led', '...
# 3  ['israeli', 'defence', 'minister', 'us', 'stri...
# 4  ['georgian', 'tv', 'reporter', 'shot', 'russia...

# %%
labels = pd.read_csv("./rsc/Combined_News_DJIA.csv", usecols = ["Label"])

if 'Label' in revisedNews.columns: 
    print("Label exists")
else:
    revisedNews.insert(loc = 0, value = 0, column = "Label")
revisedNews.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-216-5cc4e5d13087> in <module>()
#       1 labels = pd.read_csv("./rsc/Combined_News_DJIA.csv", usecols = ["Label"])
#       2
# ----> 3 if 'Label' in df.columns:
#       4     print("Label exists")
#       5 else:
#
# NameError: name 'df' is not defined

# %%
for i in range(0, len(revisedNews)):
    if int(labels.iloc[i] == 1):
        revisedNews.iloc[i,0] = "yes"
    else:
        revisedNews.iloc[i,0] = "no"

# %%
revisedNews.iloc[0,0]
# Out:
# 'no'
