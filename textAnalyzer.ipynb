# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir

import re
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
  
import string
import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
from nltk.corpus import stopwords
from tensorflow.contrib.tensorboard.plugins import projector

# %%
# Give a folder path as an argument with '--log_dir' to save
# TensorBoard summaries. Default is a log folder in current directory.
current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
FLAGS, unparsed = parser.parse_known_args()

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(FLAGS.log_dir):
  os.makedirs(FLAGS.log_dir)

# %%
def text_process(text):
    '''
    Takes in a string of text, then
    1. Removes all punctuation and stopwords
    3. Returns the clean text as a list of words
    '''
    text = str(text).lower()
    text = text[1:]
    
    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    
    output = [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]
    
    return ' '.join(output)

def read_data(filename):
    # extract the csv file with each cell as a list of strings
    file = pd.read_csv(filename, usecols=range(2,23))
    for row in range(0,1989):
        for col in range(0,21):
            file.iloc[row,col] = text_process(str(file.iloc[row,col]))
    return file

# %%
# run this to remove b and lowercase
# redditNews = read_data('./rsc/Combined_News_DJIA.csv')

# %% [markdown]
# ### print(train)

# %%
# redditNews.to_csv("./rsc/cleanedNews.csv", sep=',',index=False)
# cleanedNews = pd.read_csv("./rsc/cleanedNews.csv")
# cleanedNews.head()

# %%
cleanedNews = pd.read_csv("./rsc/cleanedNews.csv")

def convert_string(array):
    numRows = len(array)
    numCol = len(array.iloc[0])
    wordString = []
    for row in range(0,numRows):
        for col in range(0,numCol):
            wordString +=(array.iloc[row, col].split())
    return wordString

outputWordList = convert_string(cleanedNews)

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = len(set(outputWordList))
print(vocabulary_size)

outputWordList = set(outputWordList)
# Out:
# 40503

# %%
def build_dataset(words, n_words):
  #Process raw inputs into a dataset.
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary


# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(
    outputWordList, vocabulary_size)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 1], ('landings', 1), ('defiled', 1), ('magnate', 1), ('lactosefree', 1)]
# Sample data [2, 5, 7, 8, 12, 14, 15, 36894, 18, 103] ['defiled', 'blasts', 'ribbons', 'warsi', 'derry', 'rnpolish', 'eventy', 'wearing', '2042', 'iraniraq']

# %%
data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

# %%
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
# Out:
# 5 blasts -> 7 ribbons
# 5 blasts -> 2 defiled
# 7 ribbons -> 8 warsi
# 7 ribbons -> 5 blasts
# 8 warsi -> 12 derry
# 8 warsi -> 7 ribbons
# 12 derry -> 8 warsi
# 12 derry -> 14 rnpolish

# %%
graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal(
              [vocabulary_size, embedding_size],
              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(FLAGS.log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
    # Feed metadata variable to session for visualizing the graph in TensorBoard.
    _, summary, loss_val = session.run(
        [optimizer, merged, loss],
        feed_dict=feed_dict,
        run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(FLAGS.log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()
# Out:
# Initialized
# Average loss at step  0 :  312.197692871
# Nearest to liable: arafats, aunt, ph, tarot, bolsheviks, cigarette, 62yearold, forbids,
# Nearest to comprehensive: uss, stir, reelection, planted, girffin, evaporated, supercomputer, dinars,
# Nearest to selfdefinition: jokhang, legendry, joachim, tracks, exministers, cater, mustansir, 1970,
# Nearest to magnate: workweek, satirists, represented, detonates, 1017, mammoth, twoday, estaurant,
# Nearest to gasoline: accreditation, sarajevo, rofesssor, raed, wrongdoings, revolted, mahfouz, grants,
# Nearest to luladinejad: ightwing, assassinates, ias, 621, sightseeing, purposes, ishops, rompuy,
# Nearest to preferential: fragmented, lastic, kimchi, ritium, vasili, inducing, ensnaring, aghdadi,
# Nearest to entecostal: maranho, alight, investigated, land, ictoria, addaffis, problemcorruption, ocument,
# Nearest to omorrow: voicemail, onward, calculated, growop, ferdinand, prowl, binladin, waging,
# Nearest to alibaba: 300kph, 9948, provoked, uwaiti, robotic, cu, elsewhere, ontarios,
# Nearest to niamey: hortly, theology, fijians, imperialists, bushfires, eroes, congestion, consist,
# Nearest to franklin: corexit, jrg, griffin, melting, liked, everyones, network, erlin,
# Nearest to debt82: antidote, perplexing, riton, asyjet, ntidrone, sony, deliver, clearly,
# Nearest to 46m: trauma, mcmurray, israelis, bury, enticed, karzai, deadlock, himalayan,
# Nearest to sraellebanon: sikhhindu, leaderncalled, coffers, accessed, yulia, belongings, derail, dosimeter,
# Nearest to 2042: 18981944, nursery, otally, melbourne, 3000yr, light, faith, accepted,
# Average loss at step  2000 :  149.695275146
# Average loss at step  4000 :  97.7878996611
# Average loss at step  6000 :  75.6849085655
# Average loss at step  8000 :  57.9250556269
# Average loss at step  10000 :  40.5416660352
# Nearest to liable: arafats, aunt, ph, tarot, bolsheviks, cigarette, 62yearold, forbids,
# Nearest to comprehensive: uss, stir, reelection, planted, girffin, addax, evaporated, charcoal,
# Nearest to selfdefinition: legendry, jokhang, joachim, exministers, mustansir, 574, tracks, cater,
# Nearest to magnate: estaurant, detonates, represented, 1017, gunpoint, workweek, twoday, 27122012,
# Nearest to gasoline: accreditation, rofesssor, mahfouz, raed, chagos, sarajevo, esistance, revolted,
# Nearest to luladinejad: ightwing, assassinates, 621, sightseeing, umor, ishops, ias, askits,
# Nearest to preferential: vasili, fragmented, lastic, kimchi, ritium, burnedout, aghdadi, ensnaring,
# Nearest to entecostal: maranho, alight, investigated, land, ictoria, addaffis, ocument, problemcorruption,
# Nearest to omorrow: voicemail, onward, calculated, ferdinand, lure, growop, restaurant, prowl,
# Nearest to alibaba: 300kph, 9948, provoked, robotic, uwaiti, ontarios, cu, euthanasia,
# Nearest to niamey: hortly, bushfires, recovering, theology, eroes, fijians, consist, molesting,
# Nearest to franklin: corexit, griffin, jrg, brusselslockdown, liked, melting, item, antipaedophile,
# Nearest to debt82: asyjet, perplexing, riton, antidote, ntidrone, describes, clearly, sony,
# Nearest to 46m: trauma, mcmurray, bury, israelis, enticed, channels, halves, lindenhof,
# Nearest to sraellebanon: leaderncalled, accessed, sikhhindu, 56, coffers, belongings, yulia, dosimeter,
# Nearest to 2042: 18981944, faith, nursery, accepted, 3000yr, otally, lessen, quryna,
# Average loss at step  12000 :  25.4926351233
# Average loss at step  14000 :  15.7513508378
# Average loss at step  16000 :  10.2401875716
# Average loss at step  18000 :  6.86797257763
# Average loss at step  20000 :  4.93182982105
# Nearest to liable: arafats, aunt, tarot, ph, bolsheviks, cigarette, forbids, scrutinising,
# Nearest to comprehensive: uss, reelection, stir, planted, girffin, evaporated, addax, supercomputer,
# Nearest to selfdefinition: jokhang, legendry, exministers, joachim, mustansir, violators, qf28, tracks,
# Nearest to magnate: estaurant, workweek, detonates, represented, gunpoint, 1017, twoday, uighurhan,
# Nearest to gasoline: accreditation, rofesssor, sarajevo, mahfouz, revolted, flies, grants, chagos,
# Nearest to luladinejad: ightwing, assassinates, 621, ias, umor, ishops, sightseeing, dissected,
# Nearest to preferential: vasili, fragmented, lastic, ritium, kimchi, aghdadi, burnedout, normal,
# Nearest to entecostal: maranho, alight, investigated, ictoria, problemcorruption, addaffis, land, resignations,
# Nearest to omorrow: voicemail, onward, ferdinand, calculated, oneybees, antiaircraft, waging, growop,
# Nearest to alibaba: 300kph, provoked, cu, 9948, radioisotope, elsewhere, uwaiti, robotic,
# Nearest to niamey: hortly, fijians, consist, bushfires, theology, recovering, 1752, eroes,
# Nearest to franklin: corexit, griffin, jrg, melting, brusselslockdown, antipaedophile, liked, item,
# Nearest to debt82: perplexing, ntidrone, antidote, asyjet, pukkelpop, riton, bolsters, describes,
# Nearest to 46m: trauma, bury, mcmurray, deadlock, israelis, disloyal, enticed, lindenhof,
# Nearest to sraellebanon: accessed, coffers, sikhhindu, leaderncalled, belongings, 56, yulia, derail,
# Nearest to 2042: 18981944, otally, nursery, faith, accepted, yazidi, melbourne, light,
# Average loss at step  22000 :  3.39262374523
# Average loss at step  24000 :  2.53129002771
# Average loss at step  26000 :  1.92154482114
# Average loss at step  28000 :  1.51025994298
# Average loss at step  30000 :  1.20900895712
# Nearest to liable: arafats, aunt, tarot, ph, bolsheviks, cigarette, scrutinising, forbids,
# Nearest to comprehensive: uss, reelection, stir, planted, girffin, evaporated, supercomputer, addax,
# Nearest to selfdefinition: jokhang, legendry, exministers, joachim, violators, mustansir, qf28, tracks,
# Nearest to magnate: estaurant, workweek, detonates, represented, gunpoint, 1017, satirists, uighurhan,
# Nearest to gasoline: accreditation, rofesssor, sarajevo, flies, revolted, grants, mahfouz, chagos,
# Nearest to luladinejad: ightwing, assassinates, 621, ias, dissected, sightseeing, ishops, umor,
# Nearest to preferential: fragmented, vasili, lastic, ritium, kimchi, aghdadi, ensnaring, courage,
# Nearest to entecostal: maranho, alight, investigated, ictoria, problemcorruption, land, resignations, addaffis,
# Nearest to omorrow: voicemail, ferdinand, onward, calculated, oneybees, waging, antiaircraft, growop,
# Nearest to alibaba: 300kph, provoked, cu, 9948, elsewhere, radioisotope, uwaiti, robotic,
# Nearest to niamey: hortly, fijians, consist, bushfires, 1752, eroes, theology, recovering,
# Nearest to franklin: corexit, jrg, griffin, melting, brusselslockdown, antipaedophile, liked, item,
# Nearest to debt82: perplexing, ntidrone, asyjet, pukkelpop, antidote, deliver, describes, bolsters,
# Nearest to 46m: trauma, deadlock, bury, mcmurray, disloyal, israelis, enticed, channels,
# Nearest to sraellebanon: accessed, coffers, sikhhindu, belongings, yulia, leaderncalled, 56, dosimeter,
# Nearest to 2042: 18981944, otally, accepted, melbourne, light, yazidi, faith, nursery,
# Average loss at step  32000 :  0.955296096221
# Average loss at step  34000 :  0.789458858252
# Average loss at step  36000 :  0.696422395125
# Average loss at step  38000 :  0.611244549096
# Average loss at step  40000 :  0.538356244445
# Nearest to liable: arafats, aunt, tarot, ph, bolsheviks, cigarette, scrutinising, forbids,
# Nearest to comprehensive: uss, reelection, stir, planted, girffin, evaporated, supercomputer, dinars,
# Nearest to selfdefinition: jokhang, legendry, exministers, joachim, violators, mustansir, tracks, qf28,
# Nearest to magnate: estaurant, workweek, detonates, represented, gunpoint, 1017, satirists, uighurhan,
# Nearest to gasoline: accreditation, rofesssor, sarajevo, flies, grants, revolted, mahfouz, chagos,
# Nearest to luladinejad: assassinates, ightwing, 621, ias, dissected, umor, sightseeing, ishops,
# Nearest to preferential: fragmented, vasili, lastic, kimchi, ritium, ensnaring, courage, aghdadi,
# Nearest to entecostal: maranho, alight, investigated, ictoria, problemcorruption, land, resignations, addaffis,
# Nearest to omorrow: voicemail, ferdinand, onward, oneybees, waging, antiaircraft, calculated, growop,
# Nearest to alibaba: 300kph, provoked, cu, elsewhere, 9948, uwaiti, euthanasia, lashkaretaiba,
# Nearest to niamey: hortly, fijians, consist, bushfires, 1752, theology, eroes, congestion,
# Nearest to franklin: corexit, jrg, griffin, melting, liked, item, brusselslockdown, everyones,
# Nearest to debt82: perplexing, ntidrone, pukkelpop, asyjet, antidote, describes, deliver, bolsters,
# Nearest to 46m: trauma, deadlock, israelis, mcmurray, bury, disloyal, enticed, channels,
# Nearest to sraellebanon: accessed, coffers, sikhhindu, belongings, yulia, leaderncalled, 56, dosimeter,
# Nearest to 2042: 18981944, otally, accepted, melbourne, light, yazidi, faith, nursery,
# Average loss at step  42000 :  0.511444674268
# Average loss at step  44000 :  0.44956722188
# Average loss at step  46000 :  0.401642490074
# Average loss at step  48000 :  0.383667004853
# Average loss at step  50000 :  0.36907054352
# Nearest to liable: arafats, aunt, tarot, ph, cigarette, bolsheviks, scrutinising, forbids,
# Nearest to comprehensive: uss, reelection, stir, planted, evaporated, girffin, supercomputer, dinars,
# Nearest to selfdefinition: jokhang, legendry, exministers, joachim, violators, mustansir, qf28, tracks,
# Nearest to magnate: estaurant, workweek, represented, detonates, gunpoint, 1017, satirists, uighurhan,
# Nearest to gasoline: accreditation, rofesssor, sarajevo, flies, grants, revolted, mahfouz, chagos,
# Nearest to luladinejad: assassinates, ightwing, 621, ias, umor, dissected, sightseeing, organizing,
# Nearest to preferential: fragmented, lastic, vasili, ritium, kimchi, courage, ensnaring, aghdadi,
# Nearest to entecostal: maranho, alight, investigated, ictoria, problemcorruption, resignations, land, addaffis,
# Nearest to omorrow: voicemail, ferdinand, onward, oneybees, waging, antiaircraft, calculated, repelling,
# Nearest to alibaba: 300kph, provoked, cu, elsewhere, 9948, euthanasia, lashkaretaiba, uwaiti,
# Nearest to niamey: hortly, fijians, consist, bushfires, 1752, theology, eroes, congestion,
# Nearest to franklin: corexit, jrg, griffin, melting, item, everyones, liked, brusselslockdown,
# Nearest to debt82: perplexing, ntidrone, pukkelpop, asyjet, antidote, bolsters, deliver, describes,
# Nearest to 46m: trauma, deadlock, israelis, bury, disloyal, mcmurray, channels, enticed,
# Nearest to sraellebanon: accessed, coffers, sikhhindu, belongings, yulia, leaderncalled, dosimeter, 56,
# Nearest to 2042: 18981944, otally, accepted, light, melbourne, yazidi, faith, nursery,
# Average loss at step  52000 :  0.33566559536
# Average loss at step  54000 :  0.316557818644
# Average loss at step  56000 :  0.303778661184
# Average loss at step  58000 :  0.286080696195
# Average loss at step  60000 :  0.277658946253
# Nearest to liable: arafats, aunt, tarot, ph, bolsheviks, cigarette, scrutinising, forbids,
# Nearest to comprehensive: uss, reelection, stir, planted, evaporated, girffin, supercomputer, dinars,
# Nearest to selfdefinition: jokhang, legendry, exministers, joachim, violators, mustansir, 7magnitude, qf28,
# Nearest to magnate: estaurant, workweek, represented, detonates, gunpoint, 1017, satirists, uighurhan,
# Nearest to gasoline: accreditation, rofesssor, sarajevo, flies, grants, revolted, mahfouz, chagos,
# Nearest to luladinejad: assassinates, ightwing, 621, ias, umor, dissected, sightseeing, 12mile,
# Nearest to preferential: fragmented, lastic, vasili, ritium, kimchi, courage, ensnaring, aghdadi,
# Nearest to entecostal: maranho, alight, investigated, ictoria, resignations, problemcorruption, land, addaffis,
# Nearest to omorrow: voicemail, ferdinand, onward, oneybees, waging, antiaircraft, repelling, calculated,
# Nearest to alibaba: 300kph, provoked, cu, elsewhere, 9948, euthanasia, lashkaretaiba, uwaiti,
# Nearest to niamey: hortly, fijians, consist, 1752, bushfires, theology, eroes, congestion,
# Nearest to franklin: corexit, jrg, griffin, melting, everyones, item, liked, brusselslockdown,
# Nearest to debt82: perplexing, pukkelpop, ntidrone, asyjet, antidote, bolsters, deliver, describes,
# Nearest to 46m: trauma, deadlock, bury, israelis, disloyal, mcmurray, channels, enticed,
# Nearest to sraellebanon: accessed, sikhhindu, coffers, belongings, yulia, leaderncalled, dosimeter, 56,
# Nearest to 2042: 18981944, otally, accepted, light, melbourne, yazidi, nursery, atalans,
# Average loss at step  62000 :  0.262817807257
# Average loss at step  64000 :  0.25036840488
# Average loss at step  66000 :  0.242708492167
# Average loss at step  68000 :  0.233379742779
# Average loss at step  70000 :  0.225337163754
# Nearest to liable: arafats, aunt, tarot, ph, bolsheviks, cigarette, scrutinising, forbids,
# Nearest to comprehensive: uss, reelection, stir, planted, evaporated, girffin, supercomputer, dinars,
# Nearest to selfdefinition: jokhang, legendry, joachim, exministers, violators, mustansir, tracks, 7magnitude,
# Nearest to magnate: estaurant, workweek, represented, detonates, gunpoint, 1017, satirists, uighurhan,
# Nearest to gasoline: accreditation, rofesssor, sarajevo, flies, grants, revolted, mahfouz, chagos,
# Nearest to luladinejad: assassinates, ightwing, 621, ias, umor, dissected, sightseeing, organizing,
# Nearest to preferential: fragmented, lastic, vasili, ritium, kimchi, aghdadi, courage, ensnaring,
# Nearest to entecostal: maranho, alight, investigated, ictoria, resignations, problemcorruption, land, jackboot,
# Nearest to omorrow: voicemail, ferdinand, onward, oneybees, waging, antiaircraft, repelling, calculated,
# Nearest to alibaba: 300kph, provoked, cu, elsewhere, 9948, lashkaretaiba, euthanasia, masterpiece,
# Nearest to niamey: hortly, fijians, consist, bushfires, 1752, theology, congestion, eroes,
# Nearest to franklin: corexit, jrg, griffin, melting, everyones, item, brusselslockdown, liked,
# Nearest to debt82: perplexing, pukkelpop, ntidrone, antidote, asyjet, bolsters, describes, cone,
# Nearest to 46m: trauma, deadlock, israelis, bury, disloyal, mcmurray, channels, enticed,
# Nearest to sraellebanon: accessed, sikhhindu, coffers, belongings, yulia, dosimeter, leaderncalled, 56,
# Nearest to 2042: 18981944, otally, accepted, light, melbourne, yazidi, nursery, atalans,
# Average loss at step  72000 :  0.216954184651
# Average loss at step  74000 :  0.210063200556
# Average loss at step  76000 :  0.202947864983
# Average loss at step  78000 :  0.200901656721
# Average loss at step  80000 :  0.19151325025
# Nearest to liable: arafats, aunt, tarot, ph, bolsheviks, cigarette, scrutinising, forbids,
# Nearest to comprehensive: uss, reelection, stir, planted, evaporated, girffin, supercomputer, dinars,
# Nearest to selfdefinition: jokhang, legendry, joachim, exministers, violators, mustansir, 7magnitude, tracks,
# Nearest to magnate: estaurant, workweek, represented, detonates, gunpoint, 1017, satirists, uighurhan,
# Nearest to gasoline: accreditation, rofesssor, sarajevo, grants, flies, revolted, mahfouz, chagos,
# Nearest to luladinejad: assassinates, ightwing, 621, ias, umor, dissected, sightseeing, organizing,
# Nearest to preferential: fragmented, lastic, vasili, ritium, kimchi, aghdadi, courage, ensnaring,
# Nearest to entecostal: maranho, alight, investigated, ictoria, resignations, problemcorruption, land, jackboot,
# Nearest to omorrow: voicemail, ferdinand, onward, oneybees, waging, repelling, antiaircraft, calculated,
# Nearest to alibaba: 300kph, provoked, cu, elsewhere, 9948, lashkaretaiba, euthanasia, masterpiece,
# Nearest to niamey: hortly, fijians, consist, bushfires, 1752, theology, congestion, eroes,
# Nearest to franklin: corexit, jrg, griffin, melting, item, everyones, liked, brusselslockdown,
# Nearest to debt82: perplexing, pukkelpop, ntidrone, antidote, asyjet, deliver, describes, bolsters,
# Nearest to 46m: trauma, deadlock, bury, israelis, disloyal, mcmurray, channels, enticed,
# Nearest to sraellebanon: accessed, sikhhindu, coffers, belongings, yulia, dosimeter, leaderncalled, 56,
# Nearest to 2042: 18981944, otally, accepted, light, yazidi, melbourne, nursery, detour,
# Average loss at step  82000 :  0.184981413662
# Average loss at step  84000 :  0.180560027488
# Average loss at step  86000 :  0.175493862014
# Average loss at step  88000 :  0.171401835296
# Average loss at step  90000 :  0.16647900914
# Nearest to liable: arafats, tarot, aunt, ph, cigarette, bolsheviks, scrutinising, forbids,
# Nearest to comprehensive: uss, stir, reelection, planted, evaporated, girffin, supercomputer, dinars,
# Nearest to selfdefinition: jokhang, legendry, joachim, exministers, violators, 7magnitude, mustansir, tracks,
# Nearest to magnate: estaurant, workweek, represented, detonates, gunpoint, 1017, satirists, uighurhan,
# Nearest to gasoline: accreditation, rofesssor, sarajevo, grants, flies, revolted, mahfouz, chagos,
# Nearest to luladinejad: assassinates, ightwing, 621, ias, umor, dissected, sightseeing, 12mile,
# Nearest to preferential: fragmented, lastic, vasili, ritium, kimchi, aghdadi, courage, ensnaring,
# Nearest to entecostal: maranho, alight, investigated, ictoria, resignations, problemcorruption, land, jackboot,
# Nearest to omorrow: voicemail, ferdinand, onward, oneybees, waging, repelling, antiaircraft, calculated,
# Nearest to alibaba: 300kph, provoked, cu, elsewhere, 9948, lashkaretaiba, euthanasia, masterpiece,
# Nearest to niamey: hortly, fijians, consist, bushfires, 1752, theology, congestion, eroes,
# Nearest to franklin: corexit, jrg, griffin, melting, item, everyones, liked, brusselslockdown,
# Nearest to debt82: perplexing, pukkelpop, ntidrone, antidote, cone, bolsters, asyjet, describes,
# Nearest to 46m: trauma, deadlock, israelis, bury, disloyal, mcmurray, channels, enticed,
# Nearest to sraellebanon: accessed, sikhhindu, coffers, belongings, yulia, dosimeter, leaderncalled, 56,
# Nearest to 2042: 18981944, otally, accepted, light, yazidi, melbourne, nursery, detour,
# Average loss at step  92000 :  0.162276831992
# Average loss at step  94000 :  0.159242295943
# Average loss at step  96000 :  0.155389878269
# Average loss at step  98000 :  0.152405080691
# Average loss at step  100000 :  0.148739006653
# Nearest to liable: arafats, tarot, aunt, ph, bolsheviks, cigarette, scrutinising, forbids,
# Nearest to comprehensive: uss, stir, reelection, planted, evaporated, supercomputer, girffin, dinars,
# Nearest to selfdefinition: jokhang, legendry, joachim, exministers, violators, 7magnitude, mustansir, qf28,
# Nearest to magnate: estaurant, workweek, represented, gunpoint, detonates, 1017, uighurhan, satirists,
# Nearest to gasoline: accreditation, rofesssor, sarajevo, grants, flies, revolted, mahfouz, chagos,
# Nearest to luladinejad: assassinates, ightwing, 621, ias, umor, dissected, sightseeing, lankan,
# Nearest to preferential: fragmented, lastic, vasili, ritium, kimchi, courage, aghdadi, ensnaring,
# Nearest to entecostal: maranho, alight, investigated, ictoria, resignations, problemcorruption, jackboot, land,
# Nearest to omorrow: ferdinand, voicemail, onward, oneybees, waging, repelling, antiaircraft, calculated,
# Nearest to alibaba: 300kph, provoked, cu, elsewhere, 9948, lashkaretaiba, euthanasia, masterpiece,
# Nearest to niamey: hortly, fijians, consist, bushfires, 1752, theology, predominance, congestion,
# Nearest to franklin: corexit, jrg, griffin, melting, item, everyones, liked, brusselslockdown,
# Nearest to debt82: pukkelpop, perplexing, ntidrone, antidote, cone, describes, bolsters, asyjet,
# Nearest to 46m: trauma, deadlock, bury, israelis, disloyal, mcmurray, channels, enticed,
# Nearest to sraellebanon: accessed, sikhhindu, coffers, belongings, yulia, dosimeter, leaderncalled, 56,
# Nearest to 2042: 18981944, otally, accepted, light, yazidi, melbourne, detour, nursery,

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(
        label,
        xy=(x, y),
        xytext=(5, 2),
        textcoords='offset points',
        ha='right',
        va='bottom')

  plt.savefig(filename)


try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(
      perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
